# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python3 'train_justU.py'
# Out:
# learning rate: 3.0000e-04
# channel: 64
# batch size: 4
# number of epoch: 30
# data dir: ./dataset
# ckpt dir: ./checkpoint_justU
# log dir: ./log_justU
# result dir: ./result_justU
# mode: train
# TRAIN: EPOCH 00001 / 00030 | BATCH 00001 / 05926 | LOSS 1.3004
# 0.766196 sec
# TRAIN: EPOCH 00001 / 00030 | BATCH 00002 / 05926 | LOSS 1.2526
# 0.437294 sec
# TRAIN: EPOCH 00001 / 00030 | BATCH 00003 / 05926 | LOSS 1.2211
# 0.433377 sec
# TRAIN: EPOCH 00001 / 00030 | BATCH 00004 / 05926 | LOSS 1.1858
# 0.433518 sec
# TRAIN: EPOCH 00001 / 00030 | BATCH 00005 / 05926 | LOSS 1.1543
# 0.434739 sec
# TRAIN: EPOCH 00001 / 00030 | BATCH 00006 / 05926 | LOSS 1.1265
# 0.434453 sec
# TRAIN: EPOCH 00001 / 00030 | BATCH 00007 / 05926 | LOSS 1.1017
# 0.437227 sec
# TRAIN: EPOCH 00001 / 00030 | BATCH 00008 / 05926 | LOSS 1.0824
# 0.437243 sec
# TRAIN: EPOCH 00001 / 00030 | BATCH 00009 / 05926 | LOSS 1.0624
# 0.434356 sec
# TRAIN: EPOCH 00001 / 00030 | BATCH 00010 / 05926 | LOSS 1.0445
# 0.412666 sec
# ...

# %%
# !python3 "train_justU.py" --mode "test"
