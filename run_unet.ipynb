# %%
import torch
torch.cuda.is_available()

# %%
# %load_ext tensorboard

# %%
tensorboard --logdir='log_tensorboard'

# %%
# !python3 'train_justU.py'

# %%
# !python3 "train_justU.py" --mode "test"

# %%
# !python3 'train_SASA.py'

# %%
# !python3 "train_SASA.py" --mode "test"
